# %% [markdown]
# # Bayesian-free Gaussian processes
#
# Collection of datasets taken from https://www.sfu.ca/~ssurjano/optimization.html

# %%
import jax
import seaborn as sns
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (7.2, 2.3)

sns.set_palette("colorblind")

jax.config.update("jax_enable_x64", True)

# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## The noisless case

# %%
dpi = 200

# %% [markdown]
# Let $Y: {\cal X} \to \mathbb{R}$ be a random variable
# such that, for any $x_i, x_j \in {\cal X}$,
# $$
# \begin{aligned}
#     \mathbb{E}[Y(x_i)] &= 0\\
#     {\rm Cov}(Y(x_i),Y(x_j)) = \mathbb{E}[Y(x_i)\,Y(x_j)] &= k(x_i\,x_j)
# \end{aligned}
# $$
#
# where $k:\mathbb{R}^m\times\mathbb{R}^m\to\mathbb{R}$ is a valid *kernel function*.
#
# ## Problem statement
# Suppose we are given members of the sample space
# and $\{x_1, \ldots, x_t, x_{t+1}, x_{t+j}\} \subseteq {\cal X} \subseteq {\mathbb R}^m$.
# Our goal is to find the best linear unbiased predictor (BLUP) for the random variables $Y_{t+1:t+j}$
# given the subset of measurements $Y_{1:t}$.
#
# That is, we seek a matrix ${\bf A}^* \in {\mathbb R}^{j\times t}$ such that
# $$
#     {\bf A}^* = \arg\min_{{\bf A}}\mathbb{E}[\|Y_{t+1:t+j} - {\bf A}\,Y_{1:t}\|^2_2]
# $$
#
# This takes the form
#
# $$
#     {\bf A}^* = {\rm Cov}(Y_{t+1,t+j},Y_{1:T})\,{\rm Var}(Y_{1:t})^{-1}
# $$
#
# As a consequence, the best linear unbiased predictor and the error variance-covariance matrix take the form
# $$
# \begin{aligned}
#     \hat{Y}_{t+1:t+j} = {\bf A}^*\,Y_{1:t}
#     &= {\rm Cov}(Y_{t+1,t+j},Y_{1:T})\,{\rm Var}(Y_{1:t})^{-1}\,Y_{1:T}\\
#     {\rm Var}(Y_{t+1:t+j} - \hat{Y}_{t+1:t+j}) &= {\rm Var}(Y_{t+1:t+j}) - {\bf A}^*\,{\rm Var}(Y_{1:t})\,{\bf A}^{*\intercal}
# \end{aligned}
# $$

# %% [markdown]
# Because we assume knowledge of the covariance between any two elements of the sample space ${\cal X}$,
# it follows that the GP prediction is completely determined by its kernel function $k$ and sampled values for $Y_{1:t}$

# %% [markdown]
# ## Sequential update

# %%
from functools import partial

@partial(jax.vmap, in_axes=(0, None, None))
@partial(jax.vmap, in_axes=(None, 0, None))
def kgauss(u, v, sigma2=1.0):
    return jnp.exp(-(u - v) ** 2 / (2 * sigma2))
    # return jnp.exp(-(u[:, None] - v[None, :]) ** 2 / (2 * sigma2))


# def kgauss(u, v, sigma2=1.0):
#     return jnp.exp(-(u[:, None] - v[None, :]) ** 2 / (2 * sigma2))

# %%
n = 15
noise = 0.0

def f(x): return jnp.sin(4 * x) + jnp.cos(2 * x)
xtest = jnp.linspace(-4, 4, 500)
ytest = f(xtest)

key = jax.random.PRNGKey(3141)
x = jax.random.uniform(key=key, minval=-4.0, maxval=4.0, shape=(n,))
y = f(x)

# %%
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.grid(alpha=0.3)
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.savefig("interpolation-true-function.png", dpi=dpi, bbox_inches="tight")

# %%
# Estimate variance and covariances
gamma = 0.1
var_train = kgauss(x, x, gamma)
cov_test_train = kgauss(xtest, x, gamma)
var_test = kgauss(xtest, xtest, gamma)

# Make predictions
K = jnp.linalg.solve(var_train, cov_test_train.T).T
mu_pred = K @ y
sigma_pred = var_test - K @ var_train @ K.T

# %%
nobs = 5
fig, ax = plt.subplots(2, 1, sharex=True)

for n in range(nobs):
    ax[0].axvline(x[n], c="tab:gray", linewidth=1)
    ax[1].axvline(x[n], c="tab:gray", linewidth=1)
    ax[0].scatter(x[n], y[n], zorder=5, edgecolor="black", s=70)

ax[0].plot(xtest, K[:, :nobs] @ y[:nobs], c="black", linewidth=2)

# ax[0].scatter(x[:nobs], y[:nobs], marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
ax[0].set_ylabel("BLUP")
ax[0].grid(alpha=0.3)



ax[1].plot(xtest, K[:, :nobs])
ax[1].grid(alpha=0.3)
ax[1].set_yticks([-2, -1, 0.0, 1, 2])
ax[1].set_ylabel("$K_i$\ninfluence")

fig.subplots_adjust(hspace=0.0)

# %%
import numpy as np

nobs = 4

# colors = sns.color_palette("viridis", n_colors=nobs)
# colors = plt.cm.viridis(np.linspace(0, 1, nobs))
colors = plt.cm.viridis(np.linspace(0, 1, nobs))

xeval = x[:nobs]
ypred = K[:, :nobs] @ y[:nobs]

ixs = np.argsort(xeval)

# colors_interp = [((jnp.abs(Ki) / jnp.abs(Ki).sum())[:, None] * jnp.array(colors)).sum(axis=0) for Ki in K[:, ixs]]
# colors_interp = np.array(colors_interp)
colors_interp = ((np.abs(K[:, ixs]) / np.abs(K[:, ixs]).sum(axis=1, keepdims=True))[..., None] * colors).sum(axis=1)

for color, yhat, xt in zip(colors_interp, ypred, xtest):
    plt.scatter(xt, yhat, color=color[:-1], s=10)

for color, ix, in zip(colors, ixs):
    plt.scatter(x[ix], y[ix], color=color, marker="o", edgecolor="tab:gray", s=70)

plt.grid(alpha=0.3)

# %%
sns.heatmap(K.T, cmap="bone")
plt.xlabel("$x_{1:t}$")
plt.ylabel("$x_{t+1:t+j}$");

# %%
sigma_diag = jnp.diag(sigma_pred)
plt.fill_between(xtest, mu_pred + 2 * sigma_diag, mu_pred - 2 * sigma_diag, color="#ccca")
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.plot(xtest, mu_pred, c="black", linewidth=2, label="BLUP")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.grid(alpha=0.3)
plt.savefig("interpolation-estimated-function.png", dpi=dpi, bbox_inches="tight")

# %%
sigma = 0.1

n_obs_values = [0, 1, 2,  5, 10, 15]
fig, axs = plt.subplots(len(n_obs_values), 1, sharex=True, sharey=True, figsize=(7.2, 4.0 * 1.2))
for ax, n_obs in zip(axs, n_obs_values):
    var_train = kgauss(x[:n_obs], x[:n_obs], sigma)
    cov_test_train = kgauss(xtest, x[:n_obs], sigma)
    var_test = kgauss(xtest, xtest, sigma)
    
    A_blup = jnp.linalg.solve(var_train, cov_test_train.T).T
    mu_post = A_blup @ y[:n_obs]
    sigma_post = var_test - A_blup @ var_train @ A_blup.T

    upper_bound = mu_post.ravel() + 2 * jnp.diag(sigma_post)
    lower_bound = mu_post.ravel() - 2 * jnp.diag(sigma_post)
    ax.fill_between(xtest, lower_bound, upper_bound, color="#ccc5")
    ax.plot(xtest, lower_bound, c="#ccc", linewidth=1.5)
    ax.plot(xtest, upper_bound, c="#ccc", linewidth=1.5)
    
    ax.plot(xtest, ytest, label="latent function", c="crimson", linewidth=2, linestyle="--")
    ax.plot(xtest, mu_post, c="black", linewidth=2, label="BLUP")
    ax.scatter(x[:n_obs], y[:n_obs], marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
    ax.grid(alpha=0.3)
    ax.set_ylabel(f"$t={n_obs}$")

ax.set_xlabel(r"${\cal X}$")
plt.suptitle("BLUP estimation and uncertainty", y=0.92)
# plt.legend(loc="lower left", fontsize=10, framealpha=0.9)
plt.savefig("interpolation-estimated-function-steps.png", dpi=dpi, bbox_inches="tight")

# %% [markdown]
# ## Adding some noise

# %%
n = 15
var_noise = 0.2

def f(x): return jnp.sin(4 * x) + jnp.cos(2 * x)
xtest = jnp.linspace(-4, 4, 500)
ytest = f(xtest)

key = jax.random.PRNGKey(314)
key_x, key_noise = jax.random.split(key)
x = jax.random.uniform(key=key_x, minval=-4.0, maxval=4.0, shape=(n,))
noise = jax.random.normal(key_noise, shape=(n,)) * jnp.sqrt(var_noise)
y = f(x) + noise

# %%
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.grid(alpha=0.3)
plt.savefig("regression-true-function.png", dpi=dpi, bbox_inches="tight")

# %% [markdown]
# ## Predict!

# %%
# Estimate variance and covariances
gamma = 0.1
var_train = kgauss(x, x, gamma)
cov_test_train = kgauss(xtest, x, gamma)
var_test = kgauss(xtest, xtest, gamma)

In = jnp.eye(n)

# Make predictions
K = jnp.linalg.solve(var_train + var_noise * In, cov_test_train.T).T
mu_pred = K @ y
sigma_pred = var_test - K @ var_train @ K.T

# %%
sigma_diag = jnp.diag(sigma_pred)
plt.fill_between(xtest, mu_pred + 2 * sigma_diag, mu_pred - 2 * sigma_diag, color="#ccca")
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.plot(xtest, mu_pred, c="black", linewidth=2, label="BLUP")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.grid(alpha=0.3)
plt.savefig("regression-estimated-function.png", dpi=dpi, bbox_inches="tight")

# %% [markdown]
# ## Variance need not be Gaussian

# %%
n = 15
var_noise = 0.2

def f(x): return jnp.sin(4 * x) + jnp.cos(2 * x)
xtest = jnp.linspace(-4, 4, 500)
ytest = f(xtest)

key = jax.random.PRNGKey(314)
key_x, key_noise = jax.random.split(key)
x = jax.random.uniform(key=key_x, minval=-4.0, maxval=4.0, shape=(n,))
noise = jax.random.gamma(key_noise, a=var_noise, shape=(n,))
noise = noise - noise.mean()
y = f(x) + noise

# %%
noise.var()
# Out:
# Array(0.0441601, dtype=float64)

# %%
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.grid(alpha=0.3)
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.savefig("regression-gamma-true-function.png", dpi=dpi, bbox_inches="tight")

# %%
# Estimate variance and covariances
gamma = 0.1
var_train = kgauss(x, x, gamma)
cov_test_train = kgauss(xtest, x, gamma)
var_test = kgauss(xtest, xtest, gamma)

In = jnp.eye(n)

# Make predictions
K = jnp.linalg.solve(var_train + var_noise * In, cov_test_train.T).T
mu_pred = K @ y
sigma_pred = var_test - K @ var_train @ K.T

# %%
sigma_diag = jnp.diag(sigma_pred)
plt.fill_between(xtest, mu_pred + 2 * sigma_diag, mu_pred - 2 * sigma_diag, color="#ccca")
plt.plot(xtest, f(xtest), c="crimson", linewidth=2, label="true function", linestyle="--")
plt.plot(xtest, mu_pred, c="black", linewidth=2, label="BLUP")
plt.scatter(x, y, marker="o", edgecolor="black", zorder=5, label="observations", s=70, c="crimson")
plt.legend()
plt.grid(alpha=0.3)
plt.xlabel(r"${\cal X}$")
plt.ylabel("$Y$")
plt.savefig("regression-gamma-estimated-function.png", dpi=dpi, bbox_inches="tight")

# %% [markdown]
# ## Make it Gaussian

# %%
def sample_multivariate_gauss(key, mean, cov, n_samples, min=1e-7):
    dim = cov.shape[0]
    cov = (cov + cov.T) / 2
    ev = jnp.linalg.eigh(cov)
    cov = ev.eigenvectors @ jnp.diag(jnp.clip(ev.eigenvalues, min=1e-7)) @ jnp.linalg.inv(ev.eigenvectors)
    L = jnp.linalg.cholesky(cov)
    rvs = jax.random.normal(key, shape=(dim, n_samples))
    return (L @ rvs) + mean[:, None]

# %% [markdown]
# ### Example: a Gasussian kernel

# %%
def kgauss(u, v, sigma2=1.0):
    return jnp.exp(-(u[:, None] - v[None, :]) ** 2 / (2 * sigma2))

# %%
key = jax.random.PRNGKey(314)
key_x, key_sample = jax.random.split(key)

n = 1000
x = jax.random.uniform(key=key_x, minval=-1, maxval=1, shape=(n,)).sort()[:, None]
x = jnp.linspace(-1, 1, n)


fig, axs = plt.subplots(4, 1, sharex=True, sharey=True, figsize=(7.2, 4.0 * 1.2))
n_samples = 5

sigma2 = 1.0
reg = 1e-7
mean = jnp.zeros(n)

sigma2_vals = jnp.array([0.001, 0.01, 0.1, 1.0])
for ax, sigma2 in zip(axs, sigma2_vals):
    cov = kgauss(x, x, sigma2)
    sample = sample_multivariate_gauss(key_sample, mean, cov, n_samples)
    ax.plot(x, sample)
    ax.set_ylabel(rf"$\sigma^2={sigma2}$", fontsize=10)
    ax.set_xlim(-1, 1)
    ax.grid(alpha=0.3)
ax.set_xlabel(r"Sample space ${\cal X}$")
# Out:
# Text(0.5, 0, 'Sample space ${\\cal X}$')

# %% [markdown]
# ## BLUP (posterior predictive) estimation

# %%
xtest = jnp.linspace(0, 1.3, 100)
mu_prior = jnp.zeros_like(xtest)
sigma = 0.01
n_samples = 10
x = jnp.array([0.1, 0.2, 0.25, 0.8, 0.9])
y = jnp.array([1.3, 1.1, 0.9, 0.85, 0.6])

var_train = kgauss(x, x, sigma)
cov_test_train = kgauss(xtest, x, sigma)
var_test = kgauss(xtest, xtest, sigma)

A_blup = jnp.linalg.solve(var_train, cov_test_train.T).T
mu_post = A_blup @ y
sigma_post = var_test - A_blup @ var_train @ A_blup.T

posterior_sample = sample_multivariate_gauss(key, mu_post, sigma_post, n_samples=n_samples)
prior_sample = sample_multivariate_gauss(key, mu_prior, var_test, n_samples=n_samples)

fig, ax = plt.subplots(1, 2, figsize=(12, 3), sharey=True)

ax[0].plot(xtest, prior_sample, alpha=0.5, c="tab:gray");
ax[0].set_title("Prior Samples", fontsize=15)
ax[0].plot(xtest, mu_prior, c="crimson", linewidth=2)

ax[1].plot(xtest, posterior_sample, alpha=0.5, c="tab:gray");
ax[1].plot(xtest, mu_post, c="crimson", linewidth=2)
ax[1].scatter(x, y, marker="o", c="black", zorder=5)
ax[1].set_title("Posterior Samples", fontsize=15)
for axi in ax:
    axi.grid(alpha=0.3)

# %%
upper_bound = mu_post.ravel() + 2 * jnp.diag(sigma_post)
lower_bound = mu_post.ravel() - 2 * jnp.diag(sigma_post)

plt.plot(xtest, posterior_sample, alpha=0.8, c="tab:gray");
plt.plot(xtest, mu_post, c="crimson", linewidth=2)
plt.scatter(x, y, marker="o", c="black", zorder=5)
plt.fill_between(xtest, lower_bound, upper_bound, color="#ccc6")
plt.grid(alpha=0.3)
plt.xlabel(r"Sample space ${\cal X}$")
plt.ylabel(r"Observation space $Y(X_j)$")
# Out:
# Text(0, 0.5, 'Observation space $Y(X_j)$')

# %%
plt.rcParams["figure.figsize"] = (7.2, 3)

w, h = plt.figaspect(1/1.91)
fig, ax = plt.subplots(figsize=(w, h))

upper_bound = mu_post.ravel() + 2 * jnp.diag(sigma_post)
lower_bound = mu_post.ravel() - 2 * jnp.diag(sigma_post)

plt.plot(xtest, posterior_sample, alpha=0.8, c="tab:gray");
plt.plot(xtest, mu_post, c="crimson", linewidth=2)
plt.scatter(x, y, marker="o", c="black", zorder=5)
plt.fill_between(xtest, lower_bound, upper_bound, color="#ccc6")
plt.xlim(xtest.min(), xtest.max())
plt.tight_layout()
plt.axis("off")
plt.savefig("base.png", dpi=dpi, bbox_inches="tight")
